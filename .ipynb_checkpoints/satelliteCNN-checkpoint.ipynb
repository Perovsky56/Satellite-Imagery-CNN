# %%
import pandas as pd
import numpy as np
import os

import optuna
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

import xml.etree.ElementTree as ET
from PIL import Image, ImageDraw
import itertools

from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#!pip install matplotlib scikit-learn pandas seaborn optuna

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # DATASET PREPARATION

# %%
def read_img_labels(xml_path):
    XMLtree = ET.parse(xml_path)
    XMLroot = XMLtree.getroot()
    img_labels = []

    for obj in XMLroot.findall('object'):
        label_name = obj.find('name').text
        bounding_box = obj.find('bndbox')
        
        x_min = int(bounding_box.find('xmin').text)
        y_min = int(bounding_box.find('ymin').text)
        x_max = int(bounding_box.find('xmax').text)
        y_max = int(bounding_box.find('ymax').text)

        img_labels.append((label_name, (x_min, y_min, x_max, y_max)))

    return img_labels

# %%
def read_files(files):
    data = []
    dimensions = []

    for file_name in files:
        img_path = os.path.join(data_directory, 'Images', file_name + '.jpg')
        xml_path = os.path.join(data_directory, 'Labels', 'Horizontal Bounding Boxes', file_name + '.xml')

        image = Image.open(img_path)
        image_array = np.array(image)
        if (image_array.shape[2]) != 3:
            continue

        img_labels = read_img_labels(xml_path)

        for label in img_labels:
            width = abs(label[1][0] - label[1][2])
            height = abs(label[1][1] - label[1][3])
            dimensions.append(width)
            dimensions.append(height)

        data.append((image, img_labels))

    return data, dimensions

# %%
data_directory = './datasets'

with open(os.path.join(data_directory, 'ImageSets/Main/train.txt'), 'r') as f:
    train_fnames = f.read().splitlines()
    
train_data, train_obj_dimensions = read_files(train_fnames)

image = train_data[3][0]
img_to_draw = ImageDraw.Draw(image)
img_objects = train_data[3][1]

for obj in img_objects:
    img_to_draw.text((obj[1][0], obj[1][1]), obj[0], fill='black')
    img_to_draw.rectangle(obj[1], outline='yellow')
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x800>

# %% [markdown]
# # PREPROCESSING

# %%
def square_img(image):
    image_original_size = image.size
    image_desired_size = (64, 64)

    image_max_dimension = max(image_original_size)

    squares = Image.new("RGB", (image_max_dimension, image_max_dimension))

    x = (image_max_dimension - image_original_size[0]) // 2
    y = (image_max_dimension - image_original_size[1]) // 2
    squares.paste(image, (x, y))

    new_image = squares.resize(image_desired_size)

    return new_image

# %%
def object_from_image(image, image_labels):
    objects = []
    labels = []

    for label, bounding_box in image_labels:
        labels.append(label)
        obj_region = image.crop(bounding_box)
        objects.append(obj_region)

    labels = np.array(labels)

    return objects, labels

# %%
def data_prep(data):
    X_temporary = []
    y_temporary = []

    for image, image_labels in data:
        objects, labels = object_from_image(image, image_labels)

        squares = []
        for obj in objects:
            square_image = square_img(obj)
            squares.append(square_image)

        X_temporary.append(squares)
        y_temporary.append(labels)

    original_labels = list(itertools.chain(*y_temporary))
    original_labels_np = np.array(original_labels).reshape(-1, 1)

    OHEncoder = OneHotEncoder()
    y = OHEncoder.fit_transform(original_labels_np).toarray()

    n_channels = 4
    X_list = []

    for image in X_temporary:
        for obj in image:
            X_list.append(np.array(obj)/255.0)

    X = np.array(X_list)

    return X, y, original_labels_np

# %%
X, y, original_labels = data_prep(train_data)
n_labels = y.shape[1]
print("Liczba klas:", n_labels)

fig, (ax0, ax1, ax2) = plt.subplots(1, 3, figsize=(12, 3))
ax0.imshow(X[3], cmap='gray')
ax1.imshow(X[43], cmap='gray')
ax2.imshow(X[80], cmap='gray')
# Out:
# Liczba klas: 20

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=.7, random_state=10)

print("Dane treningowe:")
print(f"X_train: {X_train.shape}")
print(f"y_train: {y_train.shape}")
print("Dane testowe:")
print(f"X_test: {X_test.shape}")
print(f"y_test: {y_test.shape}")
# Out:
# Dane treningowe:
# X_train: (5468, 64, 64, 3)
# y_train: (5468, 20)
# Dane testowe:
# X_test: (2344, 64, 64, 3)
# y_test: (2344, 20)

# %% [markdown]
# # MODEL

# %%
class CNN(nn.Module):
    def __init__(self, trial):
        super(CNN, self).__init__()
        self.conv_layers = nn.Sequential()
        
        # Pierwsza warstwa konwolucyjna
        self.conv_layers.add_module('conv1', nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1))
        self.conv_layers.add_module('relu1', nn.ReLU())
        self.conv_layers.add_module('pool1', nn.AvgPool2d(kernel_size=2, stride=2))
        
        # Dodanie kolejnych warstw konwolucyjnych
        num_conv_layers = trial.suggest_int('conv_layers', 1, 3)
        in_channels = 32
        for i in range(num_conv_layers):
            out_channels = trial.suggest_int(f'filters_{i}', 32, 128, step=32)
            self.conv_layers.add_module(f'conv{i+2}', nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=1, padding=1))
            self.conv_layers.add_module(f'relu{i+2}', nn.ReLU())
            self.conv_layers.add_module(f'pool{i+2}', nn.AvgPool2d(kernel_size=2, stride=2))
            in_channels = out_channels
        
        self.flatten = nn.Flatten()
        
        # Obliczanie liczby elementów po warstwach konwolucyjnych
        self._to_linear = in_channels * (64 // (2 ** (num_conv_layers + 1))) ** 2
        
        # Warstwa gęsta
        dense_units = trial.suggest_int('units', 64, 256, step=32)
        self.fc1 = nn.Linear(self._to_linear, dense_units)
        self.fc2 = nn.Linear(dense_units, 20)
        
        # Dropout
        dropout_rate = trial.suggest_float('dropout', 0.3, 0.6, step=0.1)
        self.dropout = nn.Dropout(dropout_rate)
    
    def forward(self, x):
        x = self.conv_layers(x)
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %%
def objective(trial):
    # Przygotowanie danych
    X_train_tensor = torch.tensor(X_train, dtype=torch.float32).permute(0, 3, 1, 2)
    y_train_tensor = torch.tensor(y_train.argmax(axis=1), dtype=torch.long)
    X_test_tensor = torch.tensor(X_test, dtype=torch.float32).permute(0, 3, 1, 2)
    y_test_tensor = torch.tensor(y_test.argmax(axis=1), dtype=torch.long)
    
    train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
    test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
    
    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)
    
    # Inicjalizacja modelu
    model = CNN(trial).to(device)
    
    # Optymalizator
    learning_rate = trial.suggest_categorical('learning_rate', [1e-3, 1e-4])
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    
    # Kryterium
    criterion = nn.CrossEntropyLoss()
    
    # Trening
    for epoch in range(10):  # Możesz dostosować liczbę epok
        model.train()
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            loss.backward()
            optimizer.step()
    
    # Walidacja
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for X_batch, y_batch in test_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            outputs = model(X_batch)
            _, predicted = torch.max(outputs.data, 1)
            total += y_batch.size(0)
            correct += (predicted == y_batch).sum().item()
    
    accuracy = correct / total
    return accuracy

# Hiperparametryzacja z Optuną
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

print("Najlepsze hiperparametry: ", study.best_params)
# Out:
# [I 2024-11-27 19:21:45,718] A new study created in memory with name: no-name-dc01159a-97df-4a0f-84f8-d17f8e2a7404
# [I 2024-11-27 19:21:58,602] Trial 0 finished with value: 0.8583617747440273 and parameters: {'conv_layers': 2, 'filters_0': 64, 'filters_1': 96, 'units': 64, 'dropout': 0.5, 'learning_rate': 0.001}. Best is trial 0 with value: 0.8583617747440273.
# [I 2024-11-27 19:22:12,098] Trial 1 finished with value: 0.5989761092150171 and parameters: {'conv_layers': 3, 'filters_0': 64, 'filters_1': 64, 'filters_2': 128, 'units': 64, 'dropout': 0.3, 'learning_rate': 0.0001}. Best is trial 0 with value: 0.8583617747440273.
# [I 2024-11-27 19:22:32,051] Trial 2 finished with value: 0.7555460750853242 and parameters: {'conv_layers': 1, 'filters_0': 96, 'units': 96, 'dropout': 0.5, 'learning_rate': 0.0001}. Best is trial 0 with value: 0.8583617747440273.
# [I 2024-11-27 19:22:57,037] Trial 3 finished with value: 0.5618600682593856 and parameters: {'conv_layers': 3, 'filters_0': 128, 'filters_1': 64, 'filters_2': 64, 'units': 128, 'dropout': 0.6, 'learning_rate': 0.0001}. Best is trial 0 with value: 0.8583617747440273.
# [I 2024-11-27 19:23:12,301] Trial 4 finished with value: 0.5840443686006825 and parameters: {'conv_layers': 3, 'filters_0': 32, 'filters_1': 96, 'filters_2': 128, 'units': 256, 'dropout': 0.5, 'learning_rate': 0.0001}. Best is trial 0 with value: 0.8583617747440273.
# [I 2024-11-27 19:23:23,996] Trial 5 finished with value: 0.7133105802047781 and parameters: {'conv_layers': 1, 'filters_0': 64, 'units': 64, 'dropout': 0.3, 'learning_rate': 0.0001}. Best is trial 0 with value: 0.8583617747440273.
# [I 2024-11-27 19:23:38,149] Trial 6 finished with value: 0.7589590443686007 and parameters: {'conv_layers': 1, 'filters_0': 64, 'units': 160, 'dropout': 0.6, 'learning_rate': 0.0001}. Best is trial 0 with value: 0.8583617747440273.
# [I 2024-11-27 19:24:02,535] Trial 7 finished with value: 0.7802901023890785 and parameters: {'conv_layers': 1, 'filters_0': 96, 'units': 224, 'dropout': 0.4, 'learning_rate': 0.0001}. Best is trial 0 with value: 0.8583617747440273.
# [I 2024-11-27 19:24:16,211] Trial 8 finished with value: 0.7022184300341296 and parameters: {'conv_layers': 2, 'filters_0': 32, 'filters_1': 96, 'units': 96, 'dropout': 0.4, 'learning_rate': 0.0001}. Best is trial 0 with value: 0.8583617747440273.
# [I 2024-11-27 19:24:29,710] Trial 9 finished with value: 0.8110068259385665 and parameters: {'conv_layers': 3, 'filters_0': 32, 'filters_1': 64, 'filters_2': 64, 'units': 160, 'dropout': 0.4, 'learning_rate': 0.001}. Best is trial 0 with value: 0.8583617747440273.
# [I 2024-11-27 19:24:57,911] Trial 10 finished with value: 0.878839590443686 and parameters: {'conv_layers': 2, 'filters_0': 128, 'filters_1': 128, 'units': 192, 'dropout': 0.5, 'learning_rate': 0.001}. Best is trial 10 with value: 0.878839590443686.
# [I 2024-11-27 19:25:25,059] Trial 11 finished with value: 0.8660409556313993 and parameters: {'conv_layers': 2, 'filters_0': 128, 'filters_1': 128, 'units': 192, 'dropout': 0.5, 'learning_rate': 0.001}. Best is trial 10 with value: 0.878839590443686.
# [I 2024-11-27 19:25:52,356] Trial 12 finished with value: 0.8476962457337884 and parameters: {'conv_layers': 2, 'filters_0': 128, 'filters_1': 128, 'units': 224, 'dropout': 0.5, 'learning_rate': 0.001}. Best is trial 10 with value: 0.878839590443686.
# [I 2024-11-27 19:26:19,478] Trial 13 finished with value: 0.8801194539249146 and parameters: {'conv_layers': 2, 'filters_0': 128, 'filters_1': 128, 'units': 192, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 13 with value: 0.8801194539249146.
# [I 2024-11-27 19:26:42,291] Trial 14 finished with value: 0.8809726962457338 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 128, 'units': 192, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 14 with value: 0.8809726962457338.
# [I 2024-11-27 19:27:01,988] Trial 15 finished with value: 0.8353242320819113 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 32, 'units': 192, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 14 with value: 0.8809726962457338.
# [I 2024-11-27 19:27:25,277] Trial 16 finished with value: 0.8835324232081911 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 128, 'units': 256, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 16 with value: 0.8835324232081911.
# [I 2024-11-27 19:27:47,887] Trial 17 finished with value: 0.7350682593856656 and parameters: {'conv_layers': 3, 'filters_0': 96, 'filters_1': 128, 'filters_2': 32, 'units': 256, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 16 with value: 0.8835324232081911.
# [I 2024-11-27 19:28:12,078] Trial 18 finished with value: 0.8694539249146758 and parameters: {'conv_layers': 1, 'filters_0': 96, 'units': 224, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 16 with value: 0.8835324232081911.
# [I 2024-11-27 19:28:35,044] Trial 19 finished with value: 0.8758532423208191 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 96, 'units': 256, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 16 with value: 0.8835324232081911.
# [I 2024-11-27 19:28:47,592] Trial 20 finished with value: 0.8148464163822525 and parameters: {'conv_layers': 2, 'filters_0': 64, 'filters_1': 32, 'units': 224, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 16 with value: 0.8835324232081911.
# [I 2024-11-27 19:29:14,658] Trial 21 finished with value: 0.8536689419795221 and parameters: {'conv_layers': 2, 'filters_0': 128, 'filters_1': 128, 'units': 192, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 16 with value: 0.8835324232081911.
# [I 2024-11-27 19:29:41,515] Trial 22 finished with value: 0.8617747440273038 and parameters: {'conv_layers': 2, 'filters_0': 128, 'filters_1': 128, 'units': 128, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 16 with value: 0.8835324232081911.
# [I 2024-11-27 19:30:04,429] Trial 23 finished with value: 0.8848122866894198 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 128, 'units': 160, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 23 with value: 0.8848122866894198.
# [I 2024-11-27 19:30:26,430] Trial 24 finished with value: 0.8660409556313993 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 96, 'units': 160, 'dropout': 0.5, 'learning_rate': 0.001}. Best is trial 23 with value: 0.8848122866894198.
# [I 2024-11-27 19:30:48,316] Trial 25 finished with value: 0.8587883959044369 and parameters: {'conv_layers': 1, 'filters_0': 96, 'units': 128, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 23 with value: 0.8848122866894198.
# [I 2024-11-27 19:31:11,001] Trial 26 finished with value: 0.8016211604095563 and parameters: {'conv_layers': 3, 'filters_0': 96, 'filters_1': 128, 'filters_2': 96, 'units': 160, 'dropout': 0.5, 'learning_rate': 0.001}. Best is trial 23 with value: 0.8848122866894198.
# [I 2024-11-27 19:31:25,957] Trial 27 finished with value: 0.8767064846416383 and parameters: {'conv_layers': 2, 'filters_0': 64, 'filters_1': 96, 'units': 256, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 23 with value: 0.8848122866894198.
# [I 2024-11-27 19:31:49,591] Trial 28 finished with value: 0.8767064846416383 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 128, 'units': 224, 'dropout': 0.4, 'learning_rate': 0.001}. Best is trial 23 with value: 0.8848122866894198.
# [I 2024-11-27 19:32:12,417] Trial 29 finished with value: 0.726962457337884 and parameters: {'conv_layers': 3, 'filters_0': 96, 'filters_1': 128, 'filters_2': 32, 'units': 160, 'dropout': 0.5, 'learning_rate': 0.001}. Best is trial 23 with value: 0.8848122866894198.
# [I 2024-11-27 19:32:25,975] Trial 30 finished with value: 0.8737201365187713 and parameters: {'conv_layers': 1, 'filters_0': 64, 'units': 128, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 23 with value: 0.8848122866894198.
# [I 2024-11-27 19:32:54,174] Trial 31 finished with value: 0.863481228668942 and parameters: {'conv_layers': 2, 'filters_0': 128, 'filters_1': 128, 'units': 192, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 23 with value: 0.8848122866894198.
# [I 2024-11-27 19:33:22,044] Trial 32 finished with value: 0.8609215017064846 and parameters: {'conv_layers': 2, 'filters_0': 128, 'filters_1': 128, 'units': 192, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 23 with value: 0.8848122866894198.
# [I 2024-11-27 19:33:45,124] Trial 33 finished with value: 0.8771331058020477 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 128, 'units': 160, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 23 with value: 0.8848122866894198.
# [I 2024-11-27 19:34:10,699] Trial 34 finished with value: 0.8694539249146758 and parameters: {'conv_layers': 2, 'filters_0': 128, 'filters_1': 96, 'units': 96, 'dropout': 0.3, 'learning_rate': 0.001}. Best is trial 23 with value: 0.8848122866894198.
# [I 2024-11-27 19:34:33,899] Trial 35 finished with value: 0.8796928327645052 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 128, 'units': 224, 'dropout': 0.5, 'learning_rate': 0.001}. Best is trial 23 with value: 0.8848122866894198.
# [I 2024-11-27 19:34:50,489] Trial 36 finished with value: 0.7563993174061433 and parameters: {'conv_layers': 3, 'filters_0': 64, 'filters_1': 128, 'filters_2': 96, 'units': 192, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 23 with value: 0.8848122866894198.
# [I 2024-11-27 19:35:13,007] Trial 37 finished with value: 0.7282423208191127 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 96, 'units': 256, 'dropout': 0.6, 'learning_rate': 0.0001}. Best is trial 23 with value: 0.8848122866894198.
# [I 2024-11-27 19:35:41,718] Trial 38 finished with value: 0.8698805460750854 and parameters: {'conv_layers': 1, 'filters_0': 128, 'units': 160, 'dropout': 0.5, 'learning_rate': 0.001}. Best is trial 23 with value: 0.8848122866894198.
# [I 2024-11-27 19:36:03,470] Trial 39 finished with value: 0.6697952218430034 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 96, 'units': 64, 'dropout': 0.6, 'learning_rate': 0.0001}. Best is trial 23 with value: 0.8848122866894198.
# [I 2024-11-27 19:36:19,333] Trial 40 finished with value: 0.5379692832764505 and parameters: {'conv_layers': 3, 'filters_0': 64, 'filters_1': 128, 'filters_2': 32, 'units': 128, 'dropout': 0.5, 'learning_rate': 0.0001}. Best is trial 23 with value: 0.8848122866894198.
# [I 2024-11-27 19:36:42,664] Trial 41 finished with value: 0.8698805460750854 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 128, 'units': 224, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 23 with value: 0.8848122866894198.
# [I 2024-11-27 19:37:06,071] Trial 42 finished with value: 0.8600682593856656 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 128, 'units': 224, 'dropout': 0.5, 'learning_rate': 0.001}. Best is trial 23 with value: 0.8848122866894198.
# [I 2024-11-27 19:37:29,671] Trial 43 finished with value: 0.886518771331058 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 128, 'units': 256, 'dropout': 0.4, 'learning_rate': 0.001}. Best is trial 43 with value: 0.886518771331058.
# [I 2024-11-27 19:37:53,253] Trial 44 finished with value: 0.8762798634812287 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 128, 'units': 256, 'dropout': 0.4, 'learning_rate': 0.001}. Best is trial 43 with value: 0.886518771331058.
# [I 2024-11-27 19:38:06,762] Trial 45 finished with value: 0.8600682593856656 and parameters: {'conv_layers': 2, 'filters_0': 32, 'filters_1': 64, 'units': 256, 'dropout': 0.3, 'learning_rate': 0.001}. Best is trial 43 with value: 0.886518771331058.
# [I 2024-11-27 19:38:33,350] Trial 46 finished with value: 0.8694539249146758 and parameters: {'conv_layers': 2, 'filters_0': 128, 'filters_1': 96, 'units': 192, 'dropout': 0.4, 'learning_rate': 0.001}. Best is trial 43 with value: 0.886518771331058.
# [I 2024-11-27 19:38:50,932] Trial 47 finished with value: 0.7512798634812287 and parameters: {'conv_layers': 2, 'filters_0': 64, 'filters_1': 128, 'units': 256, 'dropout': 0.4, 'learning_rate': 0.0001}. Best is trial 43 with value: 0.886518771331058.
# [I 2024-11-27 19:39:14,595] Trial 48 finished with value: 0.867320819112628 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 128, 'units': 192, 'dropout': 0.3, 'learning_rate': 0.001}. Best is trial 43 with value: 0.886518771331058.
# [I 2024-11-27 19:39:40,184] Trial 49 finished with value: 0.867320819112628 and parameters: {'conv_layers': 1, 'filters_0': 96, 'units': 224, 'dropout': 0.4, 'learning_rate': 0.001}. Best is trial 43 with value: 0.886518771331058.
# [I 2024-11-27 19:40:07,733] Trial 50 finished with value: 0.8728668941979523 and parameters: {'conv_layers': 2, 'filters_0': 128, 'filters_1': 128, 'units': 160, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 43 with value: 0.886518771331058.
# [I 2024-11-27 19:40:31,101] Trial 51 finished with value: 0.8822525597269625 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 128, 'units': 224, 'dropout': 0.5, 'learning_rate': 0.001}. Best is trial 43 with value: 0.886518771331058.
# [I 2024-11-27 19:40:55,685] Trial 52 finished with value: 0.8809726962457338 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 128, 'units': 224, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 43 with value: 0.886518771331058.
# [I 2024-11-27 19:41:19,981] Trial 53 finished with value: 0.8946245733788396 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 128, 'units': 224, 'dropout': 0.4, 'learning_rate': 0.001}. Best is trial 53 with value: 0.8946245733788396.
# [I 2024-11-27 19:41:44,027] Trial 54 finished with value: 0.8779863481228669 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 128, 'units': 256, 'dropout': 0.4, 'learning_rate': 0.001}. Best is trial 53 with value: 0.8946245733788396.
# [I 2024-11-27 19:42:07,916] Trial 55 finished with value: 0.8515358361774744 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 128, 'units': 256, 'dropout': 0.4, 'learning_rate': 0.001}. Best is trial 53 with value: 0.8946245733788396.
# [I 2024-11-27 19:42:29,890] Trial 56 finished with value: 0.8779863481228669 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 96, 'units': 224, 'dropout': 0.4, 'learning_rate': 0.001}. Best is trial 53 with value: 0.8946245733788396.
# [I 2024-11-27 19:42:50,336] Trial 57 finished with value: 0.8178327645051194 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 32, 'units': 224, 'dropout': 0.4, 'learning_rate': 0.001}. Best is trial 53 with value: 0.8946245733788396.
# [I 2024-11-27 19:43:11,852] Trial 58 finished with value: 0.6979522184300341 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 64, 'units': 256, 'dropout': 0.5, 'learning_rate': 0.0001}. Best is trial 53 with value: 0.8946245733788396.
# [I 2024-11-27 19:43:35,238] Trial 59 finished with value: 0.8707337883959044 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 128, 'units': 224, 'dropout': 0.4, 'learning_rate': 0.001}. Best is trial 53 with value: 0.8946245733788396.
# [I 2024-11-27 19:43:59,090] Trial 60 finished with value: 0.8430034129692833 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 128, 'units': 256, 'dropout': 0.5, 'learning_rate': 0.001}. Best is trial 53 with value: 0.8946245733788396.
# [I 2024-11-27 19:44:22,691] Trial 61 finished with value: 0.889505119453925 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 128, 'units': 224, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 53 with value: 0.8946245733788396.
# [I 2024-11-27 19:44:46,380] Trial 62 finished with value: 0.8767064846416383 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 128, 'units': 192, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 53 with value: 0.8946245733788396.
# [I 2024-11-27 19:45:10,417] Trial 63 finished with value: 0.8664675767918089 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 128, 'units': 224, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 53 with value: 0.8946245733788396.
# [I 2024-11-27 19:45:34,477] Trial 64 finished with value: 0.8583617747440273 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 128, 'units': 256, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 53 with value: 0.8946245733788396.
# [I 2024-11-27 19:45:59,029] Trial 65 finished with value: 0.8340443686006825 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 128, 'units': 224, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 53 with value: 0.8946245733788396.
# [I 2024-11-27 19:46:22,216] Trial 66 finished with value: 0.8813993174061433 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 128, 'units': 192, 'dropout': 0.4, 'learning_rate': 0.001}. Best is trial 53 with value: 0.8946245733788396.
# [I 2024-11-27 19:46:40,216] Trial 67 finished with value: 0.8728668941979523 and parameters: {'conv_layers': 2, 'filters_0': 64, 'filters_1': 128, 'units': 224, 'dropout': 0.4, 'learning_rate': 0.001}. Best is trial 53 with value: 0.8946245733788396.
# [I 2024-11-27 19:47:04,522] Trial 68 finished with value: 0.8703071672354948 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 128, 'units': 192, 'dropout': 0.4, 'learning_rate': 0.001}. Best is trial 53 with value: 0.8946245733788396.
# [I 2024-11-27 19:47:28,122] Trial 69 finished with value: 0.8724402730375427 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 128, 'units': 256, 'dropout': 0.4, 'learning_rate': 0.001}. Best is trial 53 with value: 0.8946245733788396.
# [I 2024-11-27 19:47:50,491] Trial 70 finished with value: 0.8762798634812287 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 96, 'units': 192, 'dropout': 0.3, 'learning_rate': 0.001}. Best is trial 53 with value: 0.8946245733788396.
# [I 2024-11-27 19:48:13,913] Trial 71 finished with value: 0.8728668941979523 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 128, 'units': 160, 'dropout': 0.4, 'learning_rate': 0.001}. Best is trial 53 with value: 0.8946245733788396.
# [I 2024-11-27 19:48:37,010] Trial 72 finished with value: 0.890358361774744 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 128, 'units': 160, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 53 with value: 0.8946245733788396.
# [I 2024-11-27 19:49:00,689] Trial 73 finished with value: 0.8792662116040956 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 128, 'units': 160, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 53 with value: 0.8946245733788396.
# [I 2024-11-27 19:49:23,925] Trial 74 finished with value: 0.8745733788395904 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 128, 'units': 160, 'dropout': 0.5, 'learning_rate': 0.001}. Best is trial 53 with value: 0.8946245733788396.
# [I 2024-11-27 19:49:47,138] Trial 75 finished with value: 0.8771331058020477 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 128, 'units': 160, 'dropout': 0.4, 'learning_rate': 0.001}. Best is trial 53 with value: 0.8946245733788396.
# [I 2024-11-27 19:50:10,810] Trial 76 finished with value: 0.8745733788395904 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 128, 'units': 192, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 53 with value: 0.8946245733788396.
# [I 2024-11-27 19:50:33,577] Trial 77 finished with value: 0.7431740614334471 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 128, 'units': 128, 'dropout': 0.4, 'learning_rate': 0.0001}. Best is trial 53 with value: 0.8946245733788396.
# [I 2024-11-27 19:50:57,097] Trial 78 finished with value: 0.8843856655290102 and parameters: {'conv_layers': 2, 'filters_0': 96, 'filters_1': 128, 'units': 224, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 53 with value: 0.8946245733788396.
# [I 2024-11-27 19:51:14,874] Trial 79 finished with value: 0.8920648464163823 and parameters: {'conv_layers': 2, 'filters_0': 64, 'filters_1': 128, 'units': 224, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 53 with value: 0.8946245733788396.
# [I 2024-11-27 19:51:30,751] Trial 80 finished with value: 0.8796928327645052 and parameters: {'conv_layers': 2, 'filters_0': 64, 'filters_1': 96, 'units': 256, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 53 with value: 0.8946245733788396.
# [I 2024-11-27 19:51:48,713] Trial 81 finished with value: 0.8954778156996587 and parameters: {'conv_layers': 2, 'filters_0': 64, 'filters_1': 128, 'units': 224, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 81 with value: 0.8954778156996587.
# [I 2024-11-27 19:52:06,092] Trial 82 finished with value: 0.8771331058020477 and parameters: {'conv_layers': 2, 'filters_0': 64, 'filters_1': 128, 'units': 224, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 81 with value: 0.8954778156996587.
# [I 2024-11-27 19:52:23,528] Trial 83 finished with value: 0.886518771331058 and parameters: {'conv_layers': 2, 'filters_0': 64, 'filters_1': 128, 'units': 224, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 81 with value: 0.8954778156996587.
# [I 2024-11-27 19:52:40,868] Trial 84 finished with value: 0.8818259385665529 and parameters: {'conv_layers': 2, 'filters_0': 64, 'filters_1': 128, 'units': 224, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 81 with value: 0.8954778156996587.
# [I 2024-11-27 19:52:58,040] Trial 85 finished with value: 0.8630546075085325 and parameters: {'conv_layers': 2, 'filters_0': 64, 'filters_1': 128, 'units': 224, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 81 with value: 0.8954778156996587.
# [I 2024-11-27 19:53:15,165] Trial 86 finished with value: 0.878839590443686 and parameters: {'conv_layers': 2, 'filters_0': 64, 'filters_1': 128, 'units': 224, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 81 with value: 0.8954778156996587.
# [I 2024-11-27 19:53:30,711] Trial 87 finished with value: 0.8792662116040956 and parameters: {'conv_layers': 2, 'filters_0': 32, 'filters_1': 128, 'units': 224, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 81 with value: 0.8954778156996587.
# [I 2024-11-27 19:53:46,975] Trial 88 finished with value: 0.8417235494880546 and parameters: {'conv_layers': 2, 'filters_0': 64, 'filters_1': 128, 'units': 128, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 81 with value: 0.8954778156996587.
# [I 2024-11-27 19:54:00,836] Trial 89 finished with value: 0.6975255972696246 and parameters: {'conv_layers': 2, 'filters_0': 64, 'filters_1': 64, 'units': 160, 'dropout': 0.6, 'learning_rate': 0.0001}. Best is trial 81 with value: 0.8954778156996587.
# [I 2024-11-27 19:54:18,097] Trial 90 finished with value: 0.8775597269624573 and parameters: {'conv_layers': 2, 'filters_0': 64, 'filters_1': 128, 'units': 224, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 81 with value: 0.8954778156996587.
# [I 2024-11-27 19:54:35,617] Trial 91 finished with value: 0.8801194539249146 and parameters: {'conv_layers': 2, 'filters_0': 64, 'filters_1': 128, 'units': 256, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 81 with value: 0.8954778156996587.
# [I 2024-11-27 19:54:50,959] Trial 92 finished with value: 0.889505119453925 and parameters: {'conv_layers': 2, 'filters_0': 32, 'filters_1': 128, 'units': 224, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 81 with value: 0.8954778156996587.
# [I 2024-11-27 19:55:07,130] Trial 93 finished with value: 0.867320819112628 and parameters: {'conv_layers': 2, 'filters_0': 32, 'filters_1': 128, 'units': 224, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 81 with value: 0.8954778156996587.
# [I 2024-11-27 19:55:23,622] Trial 94 finished with value: 0.8720136518771331 and parameters: {'conv_layers': 2, 'filters_0': 32, 'filters_1': 128, 'units': 224, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 81 with value: 0.8954778156996587.
# [I 2024-11-27 19:55:39,209] Trial 95 finished with value: 0.8835324232081911 and parameters: {'conv_layers': 2, 'filters_0': 32, 'filters_1': 128, 'units': 224, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 81 with value: 0.8954778156996587.
# [I 2024-11-27 19:55:54,392] Trial 96 finished with value: 0.898037542662116 and parameters: {'conv_layers': 2, 'filters_0': 32, 'filters_1': 128, 'units': 192, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 96 with value: 0.898037542662116.
# [I 2024-11-27 19:56:09,637] Trial 97 finished with value: 0.8668941979522184 and parameters: {'conv_layers': 2, 'filters_0': 32, 'filters_1': 128, 'units': 192, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 96 with value: 0.898037542662116.
# [I 2024-11-27 19:56:24,641] Trial 98 finished with value: 0.8809726962457338 and parameters: {'conv_layers': 2, 'filters_0': 32, 'filters_1': 128, 'units': 160, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 96 with value: 0.898037542662116.
# [I 2024-11-27 19:56:39,925] Trial 99 finished with value: 0.8869453924914675 and parameters: {'conv_layers': 2, 'filters_0': 32, 'filters_1': 128, 'units': 192, 'dropout': 0.6, 'learning_rate': 0.001}. Best is trial 96 with value: 0.898037542662116.
# Najlepsze hiperparametry:  {'conv_layers': 2, 'filters_0': 32, 'filters_1': 128, 'units': 192, 'dropout': 0.6, 'learning_rate': 0.001}

# %%
best_trial = study.best_trial

print("Najlepsze hiperparametry: ", best_trial.params)
print("\nInformacje o najlepszym trialu:")
print(f"  Trial number: {best_trial.number}")
print(f"  Wartość: {best_trial.value}")
print(f"  Parametry: {best_trial.params}")

print("\nAtrybuty najlepszych hiperparametrów:")
for key, value in best_trial.params.items():
    print(f"  {key}: {value}")

print("\nDodatkowe informacje o najlepszym trialu:")
print(f"  State: {best_trial.state}")
print(f"  Datetime start: {best_trial.datetime_start}")
print(f"  Datetime complete: {best_trial.datetime_complete}")
print(f"  Duration: {best_trial.duration}")
# Out:
# Najlepsze hiperparametry:  {'conv_layers': 2, 'filters_0': 32, 'filters_1': 128, 'units': 192, 'dropout': 0.6, 'learning_rate': 0.001}
#
# Informacje o najlepszym trialu:
#   Trial number: 96
#   Wartość: 0.898037542662116
#   Parametry: {'conv_layers': 2, 'filters_0': 32, 'filters_1': 128, 'units': 192, 'dropout': 0.6, 'learning_rate': 0.001}
#
# Atrybuty najlepszych hiperparametrów:
#   conv_layers: 2
#   filters_0: 32
#   filters_1: 128
#   units: 192
#   dropout: 0.6
#   learning_rate: 0.001
#
# Dodatkowe informacje o najlepszym trialu:
#   State: 1
#   Datetime start: 2024-11-27 19:55:39.209292
#   Datetime complete: 2024-11-27 19:55:54.391314
#   Duration: 0:00:15.182022

# %% [raw]
# import torch
# import torch.nn as nn
# import torch.optim as optim
# import optuna
# from optuna.trial import TrialState
# from torch.utils.data import DataLoader, TensorDataset
#
# # Definicja modelu
# class CNN(nn.Module):
#     def __init__(self, conv_layers, filters, kernel_sizes, strides, dense_units, dropout_rate):
#         super(CNN, self).__init__()
#         self.conv_layers = nn.Sequential()
#
#         in_channels = 3
#         for i in range(conv_layers):
#             out_channels = filters[i]
#             kernel_size = kernel_sizes[i]
#             stride = strides[i]
#             self.conv_layers.add_module(f'conv{i+1}', nn.Conv2d(in_channels, out_channels, kernel_size=kernel_size, stride=stride, padding=1))
#             self.conv_layers.add_module(f'relu{i+1}', nn.ReLU())
#             self.conv_layers.add_module(f'pool{i+1}', nn.AvgPool2d(kernel_size=2, stride=2))
#             in_channels = out_channels
#
#         self.flatten = nn.Flatten()
#
#         # Obliczanie liczby elementów po warstwach konwolucyjnych
#         self._to_linear = in_channels * (64 // (2 ** conv_layers)) ** 2
#
#         # Warstwa gęsta
#         self.fc1 = nn.Linear(self._to_linear, dense_units)
#         self.fc2 = nn.Linear(dense_units, 20)
#
#         # Dropout
#         self.dropout = nn.Dropout(dropout_rate)
#
#     def forward(self, x):
#         x = self.conv_layers(x)
#         x = self.flatten(x)
#         x = self.fc1(x)
#         x = self.dropout(x)
#         x = self.fc2(x)
#         return x
#
# # Funkcja do tworzenia modelu z określonymi parametrami
# def create_model(conv_layers, filters, kernel_sizes, strides, dense_units, dropout_rate):
#     model = CNN(conv_layers, filters, kernel_sizes, strides, dense_units, dropout_rate)
#     return model
#
# # Funkcja optymalizacyjna dla Optuny
# def objective(trial):
#     conv_layers = trial.suggest_int('conv_layers', 1, 3)
#     filters = [trial.suggest_int(f'filters_{i}', 32, 128, step=32) for i in range(conv_layers)]
#     kernel_sizes = [trial.suggest_int(f'kernel_size_{i}', 3, 5) for i in range(conv_layers)]
#     strides = [trial.suggest_int(f'stride_{i}', 1, 2) for i in range(conv_layers)]
#     dense_units = trial.suggest_int('units', 64, 256, step=32)
#     dropout_rate = trial.suggest_float('dropout', 0.3, 0.6, step=0.1)
#
#     model = create_model(conv_layers, filters, kernel_sizes, strides, dense_units, dropout_rate).to(device)
#
#     # Przygotowanie danych
#     X_train_tensor = torch.tensor(X_train, dtype=torch.float32).permute(0, 3, 1, 2)
#     y_train_tensor = torch.tensor(y_train.argmax(axis=1), dtype=torch.long)
#     X_test_tensor = torch.tensor(X_test, dtype=torch.float32).permute(0, 3, 1, 2)
#     y_test_tensor = torch.tensor(y_test.argmax(axis=1), dtype=torch.long)
#
#     train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
#     test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
#
#     train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
#     test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)
#
#     # Optymalizator
#     learning_rate = trial.suggest_categorical('learning_rate', [1e-3, 1e-4])
#     optimizer = optim.Adam(model.parameters(), lr=learning_rate)
#
#     # Kryterium
#     criterion = nn.CrossEntropyLoss()
#
#     # Trening
#     for epoch in range(10):  # Możesz dostosować liczbę epok
#         model.train()
#         for X_batch, y_batch in train_loader:
#             X_batch, y_batch = X_batch.to(device), y_batch.to(device)
#             optimizer.zero_grad()
#             outputs = model(X_batch)
#             loss = criterion(outputs, y_batch)
#             loss.backward()
#             optimizer.step()
#
#     # Walidacja
#     model.eval()
#     correct = 0
#     total = 0
#     with torch.no_grad():
#         for X_batch, y_batch in test_loader:
#             X_batch, y_batch = X_batch.to(device), y_batch.to(device)
#             outputs = model(X_batch)
#             _, predicted = torch.max(outputs.data, 1)
#             total += y_batch.size(0)
#             correct += (predicted == y_batch).sum().item()
#
#     accuracy = correct / total
#     return accuracy
#
# # Hiperparametryzacja z Optuną
# study = optuna.create_study(direction='maximize')
# study.optimize(objective, n_trials=100)
#
# print("Najlepsze hiperparametry: ", study.best_params)
#
# # Tworzenie i trenowanie modelu z najlepszymi hiperparametrami
# best_trial_params = study.best_trial.params
#
# # Ręczne uruchomienie modelu z najlepszymi hiperparametrami lub własnymi parametrami
# conv_layers_best = best_trial_params['conv_layers']
# filters_best = [best_trial_params[f'filters_{i}'] for i in range(conv_layers_best)]
# kernel_sizes_best = [best_trial_params[f'kernel_size_{i}'] for i in range(conv_layers_best)]
# strides_best = [best_trial_params[f'stride_{i}'] for i in range(conv_layers_best)]
# dense_units_best = best_trial_params['units']
# dropout_rate_best = best_trial_params['dropout']
#
# best_model_manual_params = create_model(conv_layers_best,
#                                         filters_best,
#                                         kernel_sizes_best,
#                                         strides_best,
#                                         dense_units_best,
#                                         dropout_rate_best).to(device)
#
# # Teraz możesz ręcznie uruchomić model z własnymi parametrami:
# manual_conv_layers = 2
# manual_filters = [64, 128]
# manual_kernel_sizes = [3, 3]
# manual_strides = [1, 1]
# manual_dense_units = 128
# manual_dropout_rate = 0.5
#
# manual_model = create_model(manual_conv_layers,
#                             manual_filters,
#                             manual_kernel_sizes,
#                             manual_strides,
#                             manual_dense_units,
#                             manual_dropout_rate).to(device)
#
# print(manual_model)
